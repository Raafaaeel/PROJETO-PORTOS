# %% [markdown]
# <a href="https://colab.research.google.com/github/Raafaaeel/PROJETO-PORTOS/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
caminho_in = '/content/drive/Meu Drive/DATA/ANTAQ'

# %%
file1 = caminho_in + '/2022Atracacao.csv'

# %%
import pandas as pd
df1 = pd.read_csv(file1, low_memory=False, sep = ";", encoding="UTF-8", decimal=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2726190408.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df1 = pd.read_csv(file1, low_memory=False, sep = ";", encoding="UTF-8", decimal=',')
#
# ...
